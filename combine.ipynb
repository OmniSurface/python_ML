# %%
import matplotlib.pyplot as plt
import os, glob
import numpy as np
from scipy.fft import fft, fftfreq
import scipy.signal
import pywt
from scipy.signal import butter, lfilter

# %%
def read_file(filename):
    
    with open(filename, "r") as file:
        piezo_set = []
        mic_set = []
        for line in file:
            stripped_line = line.strip()
            if stripped_line:  
                try:
                    # try to convert the line to an integer
                    piezo_data, mic_data = stripped_line.split(',') # data format: piezo, mic
                    piezo_set.append(int(piezo_data))
                    mic_set.append(int(mic_data))
                except ValueError:
                    # handle the case where the line contains non-integer values
                    parts = stripped_line.split('\x00')
                    for part in parts:
                        if part:  
                            try:
                                piezo_data, mic_data = stripped_line.split(',') # data format: piezo, mic
                                piezo_set.append(int(piezo_data))
                                mic_set.append(int(mic_data))
                            except ValueError:
                                print(f"warning: '{part}' cannot be converted to an integer")
    piezo_set = np.array(piezo_set)
    mic_set = np.array(mic_set)
    denoised_piezo_data = wavelet_denoise(piezo_set, wavelet='db1', level=1) # 这里使用了Daubechies小波（'db1'），也就是Haar小波，分解层数为1。
    denoised_mic_data = wavelet_denoise(mic_set, wavelet='db1', level=1)
    return denoised_piezo_data, denoised_mic_data
    # return piezo_set, mic_set

def signal_visualization(piezo, mic, filename):
    plt.figure()
    plt.plot(piezo, linestyle='-', label='piezo Data') #可视化一个拳头敲击周期的动作
    plt.plot(mic, linestyle='-', label='mic Data')
    plt.title(f'Sensor Data Over Time for {filename}')
    plt.xlabel('Time (arbitrary units)')
    plt.ylabel('Sensor Value')
    # plt.ylim(0,6000)
    plt.legend()
    plt.grid(True)
    plt.show()

def fft_visualization(signal, fft_result, filename):

    fs = 6000
    
    frequencies = np.fft.fftfreq(len(fft_result), 1/fs)
    magnitude = np.abs(fft_result)

    plt.figure(figsize=(14, 7))
    plt.plot(frequencies, magnitude)
    plt.title(f'FFT of {filename}')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Magnitude')
    plt.grid(True)
    plt.xlim(0, fs / 2)  # Limit x-axis to positive frequencies only up to Nyquist frequency
    plt.show()

    return frequencies, magnitude

def fft_features(fft_results):
    # Assume fft_results is an array of FFT coefficients
    magnitude_spectrum = np.abs(fft_results)
    
    # Spectral Centroid： Indicates the "center of mass" of the spectrum, giving an idea of the "brightness" of a sound.
    spectral_centroid = np.sum(magnitude_spectrum * np.arange(len(magnitude_spectrum))) / np.sum(magnitude_spectrum)
    
    # Spectral Rolloff：The frequency below which a certain percentage of the total spectral energy (commonly 85% or 95%) is contained, which helps in differentiating between harmonic content and noise.
    spectral_rolloff_threshold = 0.85 * np.sum(magnitude_spectrum)
    cumulative_sum = np.cumsum(magnitude_spectrum)
    spectral_rolloff = np.where(cumulative_sum >= spectral_rolloff_threshold)[0][0]
    
    # Spectral Flux：Measures the amount of local spectral change between successive frames, useful for detecting events.
    spectral_flux = np.sum((np.diff(magnitude_spectrum) ** 2))
    
    # Total Spectral Energy：Sum of squares of the FFT coefficients can serve as a measure of the overall signal energy.
    total_spectral_energy = np.sum(magnitude_spectrum ** 2)
    
    return {
        'spectral_centroid': spectral_centroid,
        'spectral_rolloff': spectral_rolloff,
        'spectral_flux': spectral_flux,
        'total_spectral_energy': total_spectral_energy
    }

def wavelet_features(signal):
    wavelet_transform = scipy.signal.cwt(signal, scipy.signal.ricker, widths=np.arange(1, 31))
    wavelet_energy = np.sum(wavelet_transform**2, axis=0)
    
    features = {
        "wavelet_energy": wavelet_energy
    }
    return features



def wavelet_denoise(data, wavelet, level):
    # 小波变换
    coeff = pywt.wavedec(data, wavelet, mode='per', level=level)
    
    # 计算阈值
    sigma = np.median(np.abs(coeff[-1])) / 0.6745
    threshold = sigma * np.sqrt(2 * np.log(len(data)))
    
    # 阈值处理
    coeff[1:] = [pywt.threshold(i, value=threshold, mode='soft') for i in coeff[1:]]
    
    # 重构信号
    reconstructed_signal = pywt.waverec(coeff, wavelet, mode='per')
    return reconstructed_signal

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = scipy.signal.butter(order, [low, high], btype='band')
    y = scipy.signal.lfilter(b, a, data)
    return y

def butter_bandstop_filter(data, lowcut, highcut, fs, order=5):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = scipy.signal.butter(order, [low, high], btype='bandstop')
    y = scipy.signal.lfilter(b, a, data)
    return y

def load_data():
    features, labels = [], []
    # count = 0
    for file in glob.glob("data/combine/*/*.txt"):
        file_name = os.path.basename(file)
        label = os.path.dirname(file).split("/")[2]
        # print(file_name,label)
        piezo_signal, mic_signal = read_file(file)
        # piezo_signal_centered = piezo_signal - np.mean(piezo_signal)
        # mic_signal_centered = mic_signal - np.mean(mic_signal)
        
        piezo_fft_result = np.fft.fft(piezo_signal)
        mic_fft_result = np.fft.fft(mic_signal)
        # print(wavelet_features(piezo_signal))
        # print(fft_features(piezo_fft_result))

        piezo_spectral_feature = fft_features(piezo_fft_result)
        piezo_spectral_feature = np.array(list(piezo_spectral_feature.values()))
        piezo_wavelet_feature = wavelet_features(piezo_signal)['wavelet_energy']
        piezo_feature = np.concatenate((piezo_spectral_feature, piezo_wavelet_feature))
        # print(piezo_spectrial_feature_values)

        mic_spectral_feature = fft_features(mic_fft_result)
        mic_spectral_feature = np.array(list(mic_spectral_feature.values()))
        mic_wavelet_feature = wavelet_features(mic_signal)['wavelet_energy']
        mic_feature = np.concatenate((mic_spectral_feature, mic_wavelet_feature))

        combined_feature = np.concatenate((piezo_feature, mic_feature))

        features.append(combined_feature)
        labels.append(label)
    # print(features)
    return features, labels

# %%
# return features from a single file, method similar to load_data function
def load_single_data(file):
    piezo_signal, mic_signal = read_file(file)
    piezo_fft_result = np.fft.fft(piezo_signal)
    mic_fft_result = np.fft.fft(mic_signal)

    piezo_spectral_feature = fft_features(piezo_fft_result)
    piezo_spectral_feature = np.array(list(piezo_spectral_feature.values()))
    piezo_wavelet_feature = wavelet_features(piezo_signal)['wavelet_energy']
    piezo_feature = np.concatenate((piezo_spectral_feature, piezo_wavelet_feature))

    mic_spectral_feature = fft_features(mic_fft_result)
    mic_spectral_feature = np.array(list(mic_spectral_feature.values()))
    mic_wavelet_feature = wavelet_features(mic_signal)['wavelet_energy']
    mic_feature = np.concatenate((mic_spectral_feature, mic_wavelet_feature))

    features = np.concatenate((piezo_feature, mic_feature))

    return features

# call load_single_data function to get features from a single file, e.g. "data/combine/finger-snap/1714366681_1s_data.txt"
file = "data/combine/finger-snap/1714366682_1s_data.txt"
features = load_single_data(file)
# Out:
# /var/folders/0c/21w8m2ps1nj3wp8gv22kpyp40000gn/T/ipykernel_49319/870808706.py:88: DeprecationWarning: scipy.signal.cwt is deprecated in SciPy 1.12 and will be removed
# in SciPy 1.15. We recommend using PyWavelets instead.
#
#   wavelet_transform = scipy.signal.cwt(signal, scipy.signal.ricker, widths=np.arange(1, 31))

# %%
features[:10]
# Out:
# array([3.56701530e+02, 0.00000000e+00, 1.08927598e+14, 1.08891028e+14,
#        1.21093504e+06, 1.73582241e+07, 4.44390901e+07, 7.83110036e+07,
#        1.15246691e+08, 1.53512191e+08])

# %%
# features = load_data()[0]

# # Initialize a figure with subplots
# fig, axs = plt.subplots(4, 1, figsize=(10, 12))  # 4 rows, 1 column for each feature
# fig.suptitle('Comparison of Spectral Features Across Signals')

# # Names of features for plotting
# feature_names = ['spectral_centroid', 'spectral_rolloff', 'spectral_flux', 'total_spectral_energy']

# # Loop over each feature to create a subplot for that feature
# for i, feature in enumerate(feature_names):
#     # Extract the feature across all signals
#     values = [signal[feature] for signal in features]

#     # Plotting
#     axs[i].plot(values, marker='o', linestyle='-')  # Line plot
#     axs[i].set_title(feature)
#     axs[i].set_xlabel('Signal Index')
#     axs[i].set_ylabel('Value')

# # Adjust layout
# plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust the rect to fit the overall title
# plt.show()

# %%
# piezo_signal, mic_signal = read_file("data/1714360224_1s_data.txt")
# fs = 6000

# filtered_piezo = butter_bandstop_filter(piezo_signal, 60, 80, fs)
# filtered_piezo = butter_bandstop_filter(filtered_piezo, 200, 250, fs)

# filtered_mic = butter_bandstop_filter(mic_signal, 60, 80, fs)
# filtered_mic = butter_bandstop_filter(filtered_mic, 200, 250, fs)

# fft_piezo = np.fft.fft(piezo_signal)
# fft_mic = np.fft.fft(mic_signal)
# fft_filtered_piezo = np.fft.fft(filtered_piezo)
# fft_filtered_mic = np.fft.fft(filtered_mic)



# fft_freqs_piezo = np.fft.fftfreq(len(fft_piezo), 1/fs)
# fft_magnitude_piezo = np.abs(fft_piezo)
# fft_freqs_filtered_piezo = np.fft.fftfreq(len(fft_filtered_piezo), 1/fs)
# fft_magnitude_filtered_piezo = np.abs(fft_filtered_piezo)

# fft_freqs_mic = np.fft.fftfreq(len(fft_mic), 1/fs)
# fft_magnitude_mic = np.abs(fft_mic)
# fft_freqs_filtered_mic = np.fft.fftfreq(len(fft_filtered_mic), 1/fs)
# fft_magnitude_filtered_mic = np.abs(fft_filtered_mic)

# plt.figure(figsize=(14, 7))
# plt.subplot(2, 1, 1)
# plt.plot(fft_freqs_piezo, fft_magnitude_piezo)
# plt.plot(fft_freqs_filtered_piezo, fft_magnitude_filtered_piezo)
# plt.title('FFT of Piezo Signal')
# plt.xlabel('Frequency (Hz)')
# plt.ylabel('Magnitude')
# plt.grid(True)
# plt.xlim(0,fs/2)  # Limit x-axis to positive frequencies only up to Nyquist frequency
# plt.ylim(0, 10000)  # Limit y-axis to positive frequencies only up to Nyquist frequency

# plt.subplot(2, 1, 2)
# plt.plot(fft_freqs_mic, fft_magnitude_mic)
# plt.plot(fft_freqs_filtered_mic, fft_magnitude_filtered_mic)
# plt.title('FFT of Mic Signal')
# plt.xlabel('Frequency (Hz)')
# plt.ylabel('Magnitude')
# plt.grid(True)
# plt.xlim(0, fs/2)  # Limit x-axis to positive frequencies only up to Nyquist frequency
# plt.ylim(0, 10000)  # Limit y-axis to positive frequencies only up to Nyquist frequency

# plt.tight_layout()
# plt.show()

# %%
# import os, glob
# from sklearn.preprocessing import MinMaxScaler, StandardScaler

# finger_multiple_piezo, finger_multiple_mic = read_file("data/combine/finger-multiple/1714278475_1s_data.txt")
# finger_single_piezo, finger_single_mic = read_file("data/combine/finger-single/1714342361_1s_data.txt")
# no_gesture_piezo, no_gesture_mic = read_file("data/combine/no-gesture/1714347546_1s_data.txt")

# min_length = min(len(finger_multiple_piezo), len(finger_multiple_mic), len(finger_single_piezo), len(finger_single_mic), len(no_gesture_piezo), len(no_gesture_mic))
# finger_multiple_piezo = finger_multiple_piezo[:min_length]
# finger_multiple_mic = finger_multiple_mic[:min_length]
# finger_single_piezo = finger_single_piezo[:min_length]
# finger_single_mic = finger_single_mic[:min_length]
# no_gesture_piezo = no_gesture_piezo[:min_length]
# no_gesture_mic = no_gesture_mic[:min_length]

# fs = 6000
# fft_finger_multiple_piezo = np.fft.fft(finger_multiple_piezo)
# fft_finger_multiple_mic = np.fft.fft(finger_multiple_mic)
# fft_finger_single_piezo = np.fft.fft(finger_single_piezo)
# fft_finger_single_mic = np.fft.fft(finger_single_mic)
# fft_no_gesture_piezo = np.fft.fft(no_gesture_piezo)
# fft_no_gesture_mic = np.fft.fft(no_gesture_mic)

# freq_bins = np.fft.fftfreq(n=len(finger_multiple_piezo), d=1/fs)


# magnitude_finger_multiple_piezo = np.abs(fft_finger_multiple_piezo)
# magnitude_finger_multiple_mic = np.abs(fft_finger_multiple_mic)
# magnitude_finger_single_piezo = np.abs(fft_finger_single_piezo)
# magnitude_finger_single_mic = np.abs(fft_finger_single_mic)
# magnitude_no_gesture_piezo = np.abs(fft_no_gesture_piezo)
# magnitude_no_gesture_mic = np.abs(fft_no_gesture_mic)

# plt.figure(figsize=(12, 6))
# plt.subplot(2, 1, 1)
# plt.plot(freq_bins, magnitude_finger_multiple_piezo, label='Finger Multiple Piezo FFT')
# plt.plot(freq_bins, magnitude_finger_single_piezo, label='Finger Single Piezo FFT')
# plt.plot(freq_bins, magnitude_no_gesture_piezo, label='No Gesture Piezo FFT')
# plt.title('Piezo FFT Comparison')
# plt.xlabel('Frequency (Hz)')
# plt.ylabel('Magnitude')
# plt.xlim(0, fs/2)  # Limit x-axis to positive frequencies only up to Nyquist frequency
# plt.ylim(0, 100000)
# plt.legend()

# plt.subplot(2, 1, 2)
# plt.plot(freq_bins, magnitude_finger_multiple_mic, label='Finger Multiple Mic FFT')
# plt.plot(freq_bins, magnitude_finger_single_mic, label='Finger Single Mic FFT')
# plt.plot(freq_bins, magnitude_no_gesture_mic, label='No Gesture Mic FFT')
# plt.title('Mic FFT Comparison')
# plt.xlabel('Frequency (Hz)')
# plt.ylabel('Magnitude')
# plt.xlim(0, fs/2)  # Limit x-axis to positive frequencies only up to Nyquist frequency
# plt.ylim(0, 100000)  # Limit y-axis to better visualize the differences
# plt.legend()

# plt.tight_layout()
# plt.show()

# %%
def pad_features(features):
    max_length = max(len(f) for f in features)
    padded_features = np.array([np.pad(f, (0, max_length - len(f)), 'constant') for f in features])
    return padded_features

# %%
from sklearn.preprocessing import StandardScaler

# Assuming load_data() loads your features and labels
features, labels = load_data()
padded_features = pad_features(features)

# Now padded_features should be convertible to a numpy array
features_array = np.array(padded_features)
labels_array = np.array(labels)

# Proceed with scaling or other ML preparations
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features_array)

# # Now normalized_features is ready to be used in machine learning models
# print(normalized_features)
# Out:
# /var/folders/0c/21w8m2ps1nj3wp8gv22kpyp40000gn/T/ipykernel_49319/870808706.py:88: DeprecationWarning: scipy.signal.cwt is deprecated in SciPy 1.12 and will be removed
# in SciPy 1.15. We recommend using PyWavelets instead.
#
#   wavelet_transform = scipy.signal.cwt(signal, scipy.signal.ricker, widths=np.arange(1, 31))
# warning: '2125' cannot be converted to an integer
# warning: '2075' cannot be converted to an integer
# warning: '2124' cannot be converted to an integer
# warning: '2039' cannot be converted to an integer
# warning: '2009,2041' cannot be converted to an integer
# warning: '216192040' cannot be converted to an integer
# warning: '219002064' cannot be converted to an integer
# warning: '2012,2020' cannot be converted to an integer

# %%
features_scaled.shape
# Out:
# (404, 10136)

# %%
len(labels)
# Out:
# 404

# %%
labels
# Out:
# ['no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'no-gesture',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'nail-fling-right',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-swipe-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-fling-left',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-double-click',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'finger-swipe-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'nail-fling-up',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'slap',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'finger-fling-right',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'nail-fling-left',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-move',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'mouse-click',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'fist_pound',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'typing',
#  'finger-snap',
#  'finger-snap',
#  'finger-snap',
#  'finger-snap',
#  'finger-snap',
#  'finger-snap',
#  'finger-snap',
#  'finger-snap',
#  'finger-snap',
#  'finger-snap',
#  'finger-snap',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-up',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-fling-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'finger-swipe-down',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'alarm',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'tap-singlefinger',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'finger-swipe-right',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down',
#  'nail-fling-down']

# %% [markdown]
# # Random Forest

# %%
# save features_scaled and labels_array to "DNN data" folder
np.save("DNN data/features_scaled.npy", features_scaled)
np.save("DNN data/labels_array.npy", labels_array)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(features_scaled, labels, test_size=0.25, random_state=42)

# Train a model
model = RandomForestClassifier(n_estimators=1000, random_state=42)
model.fit(X_train, y_train)

# Predict and evaluate the model
predictions = model.predict(X_test)
print(classification_report(y_test, predictions))

# # Output the predictions and their corresponding true labels
# for i, (pred, label) in enumerate(zip(predictions, y_test)):
#     print(f"Sample {i}: Prediction = {pred}, True Label = {label}")

print(f'Support RandomForestClassifier\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'Support RandomForestClassifier\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%\n')
# Out:
#                      precision    recall  f1-score   support
#
#               alarm       1.00      1.00      1.00         6
# finger-double-click       0.86      0.75      0.80         8
#   finger-fling-down       0.00      0.00      0.00         3
#   finger-fling-left       0.75      0.75      0.75         4
#  finger-fling-right       0.33      0.50      0.40         4
#     finger-fling-up       0.00      0.00      0.00         1
#         finger-snap       1.00      1.00      1.00         2
#   finger-swipe-down       0.25      0.25      0.25         4
#   finger-swipe-left       1.00      0.17      0.29         6
#  finger-swipe-right       0.83      0.62      0.71         8
#     finger-swipe-up       0.40      0.80      0.53         5
#          fist_pound       1.00      0.75      0.86         4
#         mouse-click       0.50      1.00      0.67         2
#          mouse-move       1.00      1.00      1.00         5
#     nail-fling-down       0.60      0.60      0.60         5
#     nail-fling-left       0.50      0.33      0.40         3
#    nail-fling-right       0.00      0.00      0.00         4
#       nail-fling-up       0.57      1.00      0.73         4
#          no-gesture       1.00      1.00      1.00         5
#                slap       0.86      1.00      0.92         6
#    tap-singlefinger       1.00      1.00      1.00         6
#              typing       1.00      0.67      0.80         6
#
#            accuracy                           0.68       101
#           macro avg       0.66      0.65      0.62       101
#        weighted avg       0.73      0.68      0.68       101
#
# Support RandomForestClassifier's accuracy on training set is 100.00%
# Support RandomForestClassifier's accuracy on test set is 68.32%
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification

model = make_pipeline(StandardScaler(), LinearSVC(random_state=0, tol=1e-5))
model.fit(X_train, y_train)

# Predict and evaluate the model
predictions = model.predict(X_test)
print(classification_report(y_test, predictions))

print(f'Support Vector Machine Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'Support Vector Machine Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%\n')
# Out:
#                  precision    recall  f1-score   support
#
# finger-multiple       0.86      0.86      0.86         7
#   finger-single       0.50      0.29      0.36         7
#            fist       0.20      0.50      0.29         2
#         knuckle       0.67      0.86      0.75         7
#      no-gesture       0.75      1.00      0.86         6
#           swipe       0.00      0.00      0.00         5
#
#        accuracy                           0.62        34
#       macro avg       0.50      0.58      0.52        34
#    weighted avg       0.56      0.62      0.57        34
#
# Support Vector Machine Model's accuracy on training set is 54.55%
# Support Vector Machine Model's accuracy on test set is 61.76%
# /Users/nancyluo/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
from sklearn.neural_network import MLPClassifier

model = MLPClassifier(
    activation = 'relu',
    solver = 'adam',
)

model.fit(X_train, y_train)

# Predict and evaluate the model
predictions = model.predict(X_test)
print(classification_report(y_test, predictions))


print(f'Neural Network Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'Neural Network Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%\n')
# Out:
#                  precision    recall  f1-score   support
#
# finger-multiple       1.00      0.86      0.92         7
#   finger-single       0.75      0.43      0.55         7
#            fist       0.25      1.00      0.40         2
#         knuckle       0.83      0.71      0.77         7
#      no-gesture       0.75      0.50      0.60         6
#           swipe       0.50      0.60      0.55         5
#
#        accuracy                           0.65        34
#       macro avg       0.68      0.68      0.63        34
#    weighted avg       0.75      0.65      0.67        34
#
# Neural Network Model's accuracy on training set is 66.23%
# Neural Network Model's accuracy on test set is 64.71%
# /Users/nancyluo/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# !pip install micromlgen

# %% [markdown]
# ## Create a class mapping between labels and classes

# %%
from micromlgen import port


LABELS = ['alarm','finger-double-click','finger-fling-down',
          'finger-fling-left','finger-fling-right','finger-fling-up',
          'finger-snap','finger-swipe-down','finger-swipe-left','finger-swipe-right',
          'finger-swipe-up','fist_pound','mouse-click','mouse-move','nail-fling-down',
          'nail-fling-left','nail-fling-right','nail-fling-up','no-gesture','slap',
          'tap-singlefinger','typing'] #our existing labels
classMap = {} #create an empty dict
for i, label in zip(range(len(LABELS)),LABELS): #interate over the range and the labels at the same time 
  classMap[i]=label #fill our dict

print(classMap)

# %% [markdown]
# ## Convert the model
# use the random forest classifier

# %%
c_code = port(RF_model,classmap=classMap) #convert our model

#Let's write it into a .h file
modelFile = open("model.h", "w")
modelFile.write(c_code)
modelFile.close()

#Let's print the size of the .h file
import os
model_h_size = os.path.getsize("model.h")
print(f"Header file, model.h, is {model_h_size:,} bytes.")
print("\nOpen the side panel (refresh if needed). Double click model.h to download the file.")

# %%
import os,glob

# 指定你的文件夹路径
folder_path = 'your/folder/path'
files = glob.glob("data/combine/*/*.txt")

contents = []
for file in files:
    file_path = os.path.dirname(file)+"/"+os.path.basename(file)
    with open(file_path, 'r', encoding='utf-8') as file:
        contents.append(file.read())

# 确定最短的文件长度
min_length = min(len(content) for content in contents)

# 裁剪内容到最短长度并写回到原文件
for file_path, content in zip(files, contents):
    trimmed_content = content[:min_length]
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(trimmed_content)
    print(f"File {file_path} trimmed and saved.")
# Out:
# File data/combine/no-gesture/1714363452_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363447_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363437_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363442_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363448_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363438_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363441_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363444_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363451_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363443_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363446_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363450_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363445_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363440_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363439_1s_data.txt trimmed and saved.
# File data/combine/no-gesture/1714363449_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369013_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369021_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369016_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369009_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369015_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369019_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369022_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369010_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369017_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369020_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369012_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369011_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369023_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369018_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-right/1714369014_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367855_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367867_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367849_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367859_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367850_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367862_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367861_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367853_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367868_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367856_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367863_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367851_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367858_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367866_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367854_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367857_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367865_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367852_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-left/1714367860_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368214_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368226_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368223_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368218_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368229_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368220_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368225_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368217_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368230_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368219_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368222_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368227_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368215_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368216_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368224_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368221_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-left/1714368228_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369218_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369223_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369211_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369208_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369214_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369217_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369225_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369212_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369220_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369207_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369215_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369209_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369210_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369222_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369219_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369205_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369206_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369221_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369213_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369224_1s_data.txt trimmed and saved.
# File data/combine/finger-double-click/1714369216_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367678_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367671_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367668_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367674_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367680_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367683_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367677_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367672_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367667_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367681_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367675_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367669_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367670_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367679_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367673_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367676_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-up/1714367682_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367180_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367189_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367190_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367178_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367185_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367186_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367177_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367183_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367184_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367179_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367191_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367188_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367175_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367181_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367182_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367176_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367192_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-up/1714367187_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364365_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364357_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364360_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364352_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364358_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364351_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364363_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364354_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364366_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364353_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364361_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364356_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364364_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364349_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364355_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364362_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364350_1s_data.txt trimmed and saved.
# File data/combine/slap/1714364359_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368146_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368153_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368156_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368143_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368140_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368155_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368149_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368139_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368150_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368145_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368142_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368152_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368147_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368144_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368151_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368138_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368148_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368154_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-right/1714368141_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369082_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369076_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369087_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369079_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369084_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369091_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369088_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369081_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369086_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369077_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369083_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369080_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369089_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369090_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369085_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-left/1714369078_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364612_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364607_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364602_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364617_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364608_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364614_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364601_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364604_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364599_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364611_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364616_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364603_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364606_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364613_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364598_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364610_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364605_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364600_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364615_1s_data.txt trimmed and saved.
# File data/combine/mouse-move/1714364609_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364732_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364727_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364722_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364719_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364737_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364734_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364728_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364721_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364724_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364731_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364718_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364736_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364723_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364726_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364733_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364730_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364725_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364720_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364729_1s_data.txt trimmed and saved.
# File data/combine/mouse-click/1714364735_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365432_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365442_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365427_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365422_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365437_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365428_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365434_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365424_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365438_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365431_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365441_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365436_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365423_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365426_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365443_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365433_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365440_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365430_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365439_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365425_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365435_1s_data.txt trimmed and saved.
# File data/combine/fist_pound/1714365429_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365042_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365032_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365027_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365022_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365037_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365034_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365044_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365028_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365038_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365024_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365041_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365031_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365036_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365023_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365033_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365043_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365030_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365040_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365025_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365039_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365029_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365045_1s_data.txt trimmed and saved.
# File data/combine/typing/1714365035_1s_data.txt trimmed and saved.
# File data/combine/finger-snap/1714366689_1s_data.txt trimmed and saved.
# File data/combine/finger-snap/1714366690_1s_data.txt trimmed and saved.
# File data/combine/finger-snap/1714366685_1s_data.txt trimmed and saved.
# File data/combine/finger-snap/1714366686_1s_data.txt trimmed and saved.
# File data/combine/finger-snap/1714366683_1s_data.txt trimmed and saved.
# File data/combine/finger-snap/1714366684_1s_data.txt trimmed and saved.
# File data/combine/finger-snap/1714366691_1s_data.txt trimmed and saved.
# File data/combine/finger-snap/1714366688_1s_data.txt trimmed and saved.
# File data/combine/finger-snap/1714366681_1s_data.txt trimmed and saved.
# File data/combine/finger-snap/1714366682_1s_data.txt trimmed and saved.
# File data/combine/finger-snap/1714366687_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367306_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367299_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367295_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367303_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367300_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367296_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367309_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367305_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367302_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367294_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367298_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367307_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367304_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367308_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367297_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-up/1714367301_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368048_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368038_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368041_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368044_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368034_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368047_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368037_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368032_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368042_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368035_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368045_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368040_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368039_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368043_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368033_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368036_1s_data.txt trimmed and saved.
# File data/combine/finger-fling-down/1714368046_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367776_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367763_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367766_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367773_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367770_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367765_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367779_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367769_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367775_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367772_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367767_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367762_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367777_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367774_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367768_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367761_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367778_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367764_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-down/1714367771_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367073_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367066_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367087_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367082_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367076_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367088_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367075_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367069_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367081_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367084_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367079_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367065_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367070_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367077_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367083_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367086_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367067_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367072_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367071_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367078_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367085_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367080_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367068_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367074_1s_data.txt trimmed and saved.
# File data/combine/alarm/1714367089_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364475_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364469_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364481_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364465_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364470_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364473_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364466_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364476_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364471_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364464_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364478_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364480_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364468_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364474_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364477_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364467_1s_data.txt trimmed and saved.
# File data/combine/tap-singlefinger/1714364472_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367523_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367518_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367536_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367533_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367526_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367525_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367517_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367530_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367529_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367535_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367520_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367527_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367532_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367519_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367537_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367522_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367521_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367534_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367528_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367531_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367516_1s_data.txt trimmed and saved.
# File data/combine/finger-swipe-right/1714367524_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368922_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368937_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368932_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368927_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368924_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368931_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368934_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368928_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368926_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368933_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368936_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368923_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368929_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368935_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368930_1s_data.txt trimmed and saved.
# File data/combine/nail-fling-down/1714368925_1s_data.txt trimmed and saved.

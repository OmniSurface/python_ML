# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from sklearn.metrics import classification_report
import os

# 读取数据
folder_path = 'DNN data'
# read features_scaled and labels
features_scaled = np.load(os.path.join(folder_path, 'features_scaled.npy'))
labels = np.load(os.path.join(folder_path, 'labels.npy'))


# 假设 features_scaled 已经定义为一个NumPy数组
# 将标签从字符串转换为整数
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# 分割数据集
X_train, X_test, y_train, y_test = train_test_split(features_scaled, labels_encoded, test_size=0.25, random_state=42)

# 定义模型
model = Sequential()
model.add(Dense(512, input_dim=10136, activation='relu'))  # 第一层含512个节点
model.add(Dropout(0.5))  # Dropout层防止过拟合
model.add(Dense(256, activation='relu'))  # 第二层
model.add(Dropout(0.5))  # 另一层Dropout
model.add(Dense(128, activation='relu'))  # 第三层
model.add(Dense(len(np.unique(labels_encoded)), activation='softmax'))  # 输出层，节点数为类别数，激活函数使用softmax

# 编译模型
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 训练模型
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# 评估模型
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss:.2f}")
print(f"Test Accuracy: {accuracy*100:.2f}%")

# 预测并输出分类报告
predictions = model.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)
print(classification_report(y_test, predicted_classes, target_names=encoder.classes_))
# Out:
# Epoch 1/50
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.1026 - loss: 4.2819 - val_accuracy: 0.1639 - val_loss: 3.7046
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.1855 - loss: 4.3033 - val_accuracy: 0.2131 - val_loss: 3.0325
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2864 - loss: 3.6069 - val_accuracy: 0.2787 - val_loss: 3.5574
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3245 - loss: 3.5722 - val_accuracy: 0.2951 - val_loss: 3.8701
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4222 - loss: 2.4222 - val_accuracy: 0.3115 - val_loss: 3.4390
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4210 - loss: 3.0467 - val_accuracy: 0.3770 - val_loss: 3.6457
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4525 - loss: 3.5202 - val_accuracy: 0.3115 - val_loss: 5.5836
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4543 - loss: 2.8412 - val_accuracy: 0.3279 - val_loss: 4.7706
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5182 - loss: 2.3205 - val_accuracy: 0.4262 - val_loss: 3.9409
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5391 - loss: 1.8014 - val_accuracy: 0.3934 - val_loss: 3.8807
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5106 - loss: 2.6794 - val_accuracy: 0.3607 - val_loss: 4.5003
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5272 - loss: 1.8673 - val_accuracy: 0.3770 - val_loss: 4.6750
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5496 - loss: 1.6397 - val_accuracy: 0.4262 - val_loss: 4.1030
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5443 - loss: 1.7691 - val_accuracy: 0.3607 - val_loss: 3.8834
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5798 - loss: 1.6291 - val_accuracy: 0.3443 - val_loss: 3.9126
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6430 - loss: 1.5457 - val_accuracy: 0.3607 - val_loss: 3.8348
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6503 - loss: 1.2320 - val_accuracy: 0.4426 - val_loss: 3.7650
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5966 - loss: 1.3742 - val_accuracy: 0.4918 - val_loss: 3.7909
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5755 - loss: 1.2903 - val_accuracy: 0.4754 - val_loss: 3.5039
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5983 - loss: 1.8202 - val_accuracy: 0.4754 - val_loss: 3.5232
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6827 - loss: 1.0977 - val_accuracy: 0.4590 - val_loss: 3.7471
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6320 - loss: 1.3558 - val_accuracy: 0.4754 - val_loss: 3.7183
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6597 - loss: 1.1628 - val_accuracy: 0.4754 - val_loss: 3.4663
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6908 - loss: 1.2096 - val_accuracy: 0.5410 - val_loss: 3.4261
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7452 - loss: 1.4992 - val_accuracy: 0.5410 - val_loss: 4.0678
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6329 - loss: 1.1429 - val_accuracy: 0.4918 - val_loss: 4.5982
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7162 - loss: 0.9927 - val_accuracy: 0.4590 - val_loss: 4.7105
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7026 - loss: 0.9566 - val_accuracy: 0.4918 - val_loss: 4.4220
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7053 - loss: 1.1827 - val_accuracy: 0.4426 - val_loss: 4.6704
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6638 - loss: 0.9722 - val_accuracy: 0.4426 - val_loss: 5.0128
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7184 - loss: 1.2415 - val_accuracy: 0.4918 - val_loss: 5.2049
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6621 - loss: 0.9275 - val_accuracy: 0.4426 - val_loss: 5.5944
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6726 - loss: 1.3776 - val_accuracy: 0.4262 - val_loss: 5.0706
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7565 - loss: 1.3625 - val_accuracy: 0.4426 - val_loss: 4.7599
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7402 - loss: 0.7636 - val_accuracy: 0.4590 - val_loss: 4.8652
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7397 - loss: 1.0290 - val_accuracy: 0.4590 - val_loss: 5.1444
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7318 - loss: 0.8058 - val_accuracy: 0.4754 - val_loss: 5.4304
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7337 - loss: 0.6775 - val_accuracy: 0.4426 - val_loss: 5.3844
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7270 - loss: 0.7392 - val_accuracy: 0.4426 - val_loss: 5.2455
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7473 - loss: 0.8971 - val_accuracy: 0.5410 - val_loss: 4.8091
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7387 - loss: 0.9465 - val_accuracy: 0.4918 - val_loss: 4.6002
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7778 - loss: 0.6294 - val_accuracy: 0.5082 - val_loss: 4.3612
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7245 - loss: 1.2313 - val_accuracy: 0.4426 - val_loss: 4.5364
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7630 - loss: 0.6176 - val_accuracy: 0.4754 - val_loss: 4.7539
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7070 - loss: 0.9604 - val_accuracy: 0.4590 - val_loss: 5.3496
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7434 - loss: 0.8834 - val_accuracy: 0.4590 - val_loss: 5.2777
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7968 - loss: 0.7273 - val_accuracy: 0.4918 - val_loss: 4.8789
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7445 - loss: 0.9391 - val_accuracy: 0.4262 - val_loss: 4.5190
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7662 - loss: 0.7454 - val_accuracy: 0.4098 - val_loss: 4.4040
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7568 - loss: 0.6455 - val_accuracy: 0.4590 - val_loss: 4.8706
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5880 - loss: 5.0350
# Test Loss: 4.58
# Test Accuracy: 57.43%
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#                      precision    recall  f1-score   support
#
#               alarm       1.00      0.50      0.67         6
# finger-double-click       0.70      0.88      0.78         8
#   finger-fling-down       0.50      0.33      0.40         3
#   finger-fling-left       0.75      0.75      0.75         4
#  finger-fling-right       0.20      0.25      0.22         4
#     finger-fling-up       0.00      0.00      0.00         1
#         finger-snap       0.00      0.00      0.00         2
#   finger-swipe-down       0.00      0.00      0.00         4
#   finger-swipe-left       0.50      0.33      0.40         6
#  finger-swipe-right       0.60      0.75      0.67         8
#     finger-swipe-up       0.50      0.80      0.62         5
#          fist_pound       0.50      1.00      0.67         4
#         mouse-click       0.50      1.00      0.67         2
#          mouse-move       1.00      1.00      1.00         5
#     nail-fling-down       0.71      1.00      0.83         5
#     nail-fling-left       0.25      0.33      0.29         3
#    nail-fling-right       0.00      0.00      0.00         4
#       nail-fling-up       0.00      0.00      0.00         4
#          no-gesture       0.62      1.00      0.77         5
#                slap       1.00      0.33      0.50         6
#    tap-singlefinger       1.00      0.50      0.67         6
#              typing       1.00      0.67      0.80         6
#
#            accuracy                           0.57       101
#           macro avg       0.52      0.52      0.49       101
#        weighted avg       0.60      0.57      0.55       101
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
features_scaled.shape
# Out:
# (404, 10136)

# %%
labels
# Out:
# array(['no-gesture', 'no-gesture', 'no-gesture', 'no-gesture',
#        'no-gesture', 'no-gesture', 'no-gesture', 'no-gesture',
#        'no-gesture', 'no-gesture', 'no-gesture', 'no-gesture',
#        'no-gesture', 'no-gesture', 'no-gesture', 'no-gesture',
#        'nail-fling-right', 'nail-fling-right', 'nail-fling-right',
#        'nail-fling-right', 'nail-fling-right', 'nail-fling-right',
#        'nail-fling-right', 'nail-fling-right', 'nail-fling-right',
#        'nail-fling-right', 'nail-fling-right', 'nail-fling-right',
#        'nail-fling-right', 'nail-fling-right', 'nail-fling-right',
#        'finger-swipe-left', 'finger-swipe-left', 'finger-swipe-left',
#        'finger-swipe-left', 'finger-swipe-left', 'finger-swipe-left',
#        'finger-swipe-left', 'finger-swipe-left', 'finger-swipe-left',
#        'finger-swipe-left', 'finger-swipe-left', 'finger-swipe-left',
#        'finger-swipe-left', 'finger-swipe-left', 'finger-swipe-left',
#        'finger-swipe-left', 'finger-swipe-left', 'finger-swipe-left',
#        'finger-swipe-left', 'finger-fling-left', 'finger-fling-left',
#        'finger-fling-left', 'finger-fling-left', 'finger-fling-left',
#        'finger-fling-left', 'finger-fling-left', 'finger-fling-left',
#        'finger-fling-left', 'finger-fling-left', 'finger-fling-left',
#        'finger-fling-left', 'finger-fling-left', 'finger-fling-left',
#        'finger-fling-left', 'finger-fling-left', 'finger-fling-left',
#        'finger-double-click', 'finger-double-click',
#        'finger-double-click', 'finger-double-click',
#        'finger-double-click', 'finger-double-click',
#        'finger-double-click', 'finger-double-click',
#        'finger-double-click', 'finger-double-click',
#        'finger-double-click', 'finger-double-click',
#        'finger-double-click', 'finger-double-click',
#        'finger-double-click', 'finger-double-click',
#        'finger-double-click', 'finger-double-click',
#        'finger-double-click', 'finger-double-click',
#        'finger-double-click', 'finger-swipe-up', 'finger-swipe-up',
#        'finger-swipe-up', 'finger-swipe-up', 'finger-swipe-up',
#        'finger-swipe-up', 'finger-swipe-up', 'finger-swipe-up',
#        'finger-swipe-up', 'finger-swipe-up', 'finger-swipe-up',
#        'finger-swipe-up', 'finger-swipe-up', 'finger-swipe-up',
#        'finger-swipe-up', 'finger-swipe-up', 'finger-swipe-up',
#        'nail-fling-up', 'nail-fling-up', 'nail-fling-up', 'nail-fling-up',
#        'nail-fling-up', 'nail-fling-up', 'nail-fling-up', 'nail-fling-up',
#        'nail-fling-up', 'nail-fling-up', 'nail-fling-up', 'nail-fling-up',
#        'nail-fling-up', 'nail-fling-up', 'nail-fling-up', 'nail-fling-up',
#        'nail-fling-up', 'nail-fling-up', 'slap', 'slap', 'slap', 'slap',
#        'slap', 'slap', 'slap', 'slap', 'slap', 'slap', 'slap', 'slap',
#        'slap', 'slap', 'slap', 'slap', 'slap', 'slap',
#        'finger-fling-right', 'finger-fling-right', 'finger-fling-right',
#        'finger-fling-right', 'finger-fling-right', 'finger-fling-right',
#        'finger-fling-right', 'finger-fling-right', 'finger-fling-right',
#        'finger-fling-right', 'finger-fling-right', 'finger-fling-right',
#        'finger-fling-right', 'finger-fling-right', 'finger-fling-right',
#        'finger-fling-right', 'finger-fling-right', 'finger-fling-right',
#        'finger-fling-right', 'nail-fling-left', 'nail-fling-left',
#        'nail-fling-left', 'nail-fling-left', 'nail-fling-left',
#        'nail-fling-left', 'nail-fling-left', 'nail-fling-left',
#        'nail-fling-left', 'nail-fling-left', 'nail-fling-left',
#        'nail-fling-left', 'nail-fling-left', 'nail-fling-left',
#        'nail-fling-left', 'nail-fling-left', 'mouse-move', 'mouse-move',
#        'mouse-move', 'mouse-move', 'mouse-move', 'mouse-move',
#        'mouse-move', 'mouse-move', 'mouse-move', 'mouse-move',
#        'mouse-move', 'mouse-move', 'mouse-move', 'mouse-move',
#        'mouse-move', 'mouse-move', 'mouse-move', 'mouse-move',
#        'mouse-move', 'mouse-move', 'mouse-click', 'mouse-click',
#        'mouse-click', 'mouse-click', 'mouse-click', 'mouse-click',
#        'mouse-click', 'mouse-click', 'mouse-click', 'mouse-click',
#        'mouse-click', 'mouse-click', 'mouse-click', 'mouse-click',
#        'mouse-click', 'mouse-click', 'mouse-click', 'mouse-click',
#        'mouse-click', 'mouse-click', 'fist_pound', 'fist_pound',
#        'fist_pound', 'fist_pound', 'fist_pound', 'fist_pound',
#        'fist_pound', 'fist_pound', 'fist_pound', 'fist_pound',
#        'fist_pound', 'fist_pound', 'fist_pound', 'fist_pound',
#        'fist_pound', 'fist_pound', 'fist_pound', 'fist_pound',
#        'fist_pound', 'fist_pound', 'fist_pound', 'fist_pound', 'typing',
#        'typing', 'typing', 'typing', 'typing', 'typing', 'typing',
#        'typing', 'typing', 'typing', 'typing', 'typing', 'typing',
#        'typing', 'typing', 'typing', 'typing', 'typing', 'typing',
#        'typing', 'typing', 'typing', 'typing', 'finger-snap',
#        'finger-snap', 'finger-snap', 'finger-snap', 'finger-snap',
#        'finger-snap', 'finger-snap', 'finger-snap', 'finger-snap',
#        'finger-snap', 'finger-snap', 'finger-fling-up', 'finger-fling-up',
#        'finger-fling-up', 'finger-fling-up', 'finger-fling-up',
#        'finger-fling-up', 'finger-fling-up', 'finger-fling-up',
#        'finger-fling-up', 'finger-fling-up', 'finger-fling-up',
#        'finger-fling-up', 'finger-fling-up', 'finger-fling-up',
#        'finger-fling-up', 'finger-fling-up', 'finger-fling-down',
#        'finger-fling-down', 'finger-fling-down', 'finger-fling-down',
#        'finger-fling-down', 'finger-fling-down', 'finger-fling-down',
#        'finger-fling-down', 'finger-fling-down', 'finger-fling-down',
#        'finger-fling-down', 'finger-fling-down', 'finger-fling-down',
#        'finger-fling-down', 'finger-fling-down', 'finger-fling-down',
#        'finger-fling-down', 'finger-swipe-down', 'finger-swipe-down',
#        'finger-swipe-down', 'finger-swipe-down', 'finger-swipe-down',
#        'finger-swipe-down', 'finger-swipe-down', 'finger-swipe-down',
#        'finger-swipe-down', 'finger-swipe-down', 'finger-swipe-down',
#        'finger-swipe-down', 'finger-swipe-down', 'finger-swipe-down',
#        'finger-swipe-down', 'finger-swipe-down', 'finger-swipe-down',
#        'finger-swipe-down', 'finger-swipe-down', 'alarm', 'alarm',
#        'alarm', 'alarm', 'alarm', 'alarm', 'alarm', 'alarm', 'alarm',
#        'alarm', 'alarm', 'alarm', 'alarm', 'alarm', 'alarm', 'alarm',
#        'alarm', 'alarm', 'alarm', 'alarm', 'alarm', 'alarm', 'alarm',
#        'alarm', 'alarm', 'tap-singlefinger', 'tap-singlefinger',
#        'tap-singlefinger', 'tap-singlefinger', 'tap-singlefinger',
#        'tap-singlefinger', 'tap-singlefinger', 'tap-singlefinger',
#        'tap-singlefinger', 'tap-singlefinger', 'tap-singlefinger',
#        'tap-singlefinger', 'tap-singlefinger', 'tap-singlefinger',
#        'tap-singlefinger', 'tap-singlefinger', 'tap-singlefinger',
#        'finger-swipe-right', 'finger-swipe-right', 'finger-swipe-right',
#        'finger-swipe-right', 'finger-swipe-right', 'finger-swipe-right',
#        'finger-swipe-right', 'finger-swipe-right', 'finger-swipe-right',
#        'finger-swipe-right', 'finger-swipe-right', 'finger-swipe-right',
#        'finger-swipe-right', 'finger-swipe-right', 'finger-swipe-right',
#        'finger-swipe-right', 'finger-swipe-right', 'finger-swipe-right',
#        'finger-swipe-right', 'finger-swipe-right', 'finger-swipe-right',
#        'finger-swipe-right', 'nail-fling-down', 'nail-fling-down',
#        'nail-fling-down', 'nail-fling-down', 'nail-fling-down',
#        'nail-fling-down', 'nail-fling-down', 'nail-fling-down',
#        'nail-fling-down', 'nail-fling-down', 'nail-fling-down',
#        'nail-fling-down', 'nail-fling-down', 'nail-fling-down',
#        'nail-fling-down', 'nail-fling-down'], dtype='<U19')

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report
import os

# 读取数据
folder_path = 'DNN data'
features_scaled = np.load(os.path.join(folder_path, 'features_scaled.npy'))
labels = np.load(os.path.join(folder_path, 'labels.npy'))

# 将标签从字符串转换为整数
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# 分割数据集
X_train, X_test, y_train, y_test = train_test_split(features_scaled, labels_encoded, test_size=0.25, random_state=42)

# 定义模型
model = Sequential()
model.add(Dense(1024, input_dim=10136, activation='relu'))  # 增加第一层节点数至1024
model.add(Dropout(0.3))  # 降低Dropout率以防止过度抑制有效特征
model.add(Dense(512, activation='relu'))  # 第二层
model.add(Dropout(0.3))  # 同上
model.add(Dense(256, activation='relu'))  # 新增第三层
model.add(Dense(len(np.unique(labels_encoded)), activation='softmax'))  # 输出层，节点数为类别数，激活函数使用softmax

# 编译模型
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 设置回调函数
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001, verbose=1)

# 训练模型
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1, callbacks=[early_stopping, reduce_lr])

# 评估模型
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss:.2f}")
print(f"Test Accuracy: {accuracy*100:.2f}%")

# 预测并输出分类报告
predictions = model.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)
print(classification_report(y_test, predicted_classes, target_names=encoder.classes_))
# Out:
# Epoch 1/100
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.1499 - loss: 3.5424 - val_accuracy: 0.3443 - val_loss: 3.6504 - learning_rate: 0.0010
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4707 - loss: 2.7569 - val_accuracy: 0.3443 - val_loss: 3.8925 - learning_rate: 0.0010
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5177 - loss: 1.6382 - val_accuracy: 0.4426 - val_loss: 4.7900 - learning_rate: 0.0010
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5967 - loss: 1.8565 - val_accuracy: 0.3279 - val_loss: 4.7056 - learning_rate: 0.0010
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6307 - loss: 1.6119 - val_accuracy: 0.4262 - val_loss: 4.1002 - learning_rate: 0.0010
# Epoch 6/100
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6735 - loss: 1.2588
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6699 - loss: 1.4034 - val_accuracy: 0.4754 - val_loss: 3.7214 - learning_rate: 0.0010
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6952 - loss: 1.2738 - val_accuracy: 0.4262 - val_loss: 3.7221 - learning_rate: 2.0000e-04
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7393 - loss: 0.9152 - val_accuracy: 0.4754 - val_loss: 3.5562 - learning_rate: 2.0000e-04
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7821 - loss: 0.6655 - val_accuracy: 0.4754 - val_loss: 3.6219 - learning_rate: 2.0000e-04
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7913 - loss: 0.6110 - val_accuracy: 0.4754 - val_loss: 3.7124 - learning_rate: 2.0000e-04
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7907 - loss: 0.6345 - val_accuracy: 0.4918 - val_loss: 3.7781 - learning_rate: 2.0000e-04
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8178 - loss: 0.4983 - val_accuracy: 0.5246 - val_loss: 3.7501 - learning_rate: 2.0000e-04
# Epoch 13/100
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7984 - loss: 0.6709
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7963 - loss: 0.6394 - val_accuracy: 0.5410 - val_loss: 4.2420 - learning_rate: 2.0000e-04
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7662 - loss: 0.6127 - val_accuracy: 0.5410 - val_loss: 4.3035 - learning_rate: 1.0000e-04
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7958 - loss: 0.5934 - val_accuracy: 0.5410 - val_loss: 4.2226 - learning_rate: 1.0000e-04
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8068 - loss: 0.5232 - val_accuracy: 0.5574 - val_loss: 4.1431 - learning_rate: 1.0000e-04
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8116 - loss: 0.5016 - val_accuracy: 0.5410 - val_loss: 4.0834 - learning_rate: 1.0000e-04
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8315 - loss: 0.4951 - val_accuracy: 0.5410 - val_loss: 4.0481 - learning_rate: 1.0000e-04
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6016 - loss: 3.3189
# Test Loss: 3.56
# Test Accuracy: 57.43%
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#                      precision    recall  f1-score   support
#
#               alarm       0.75      0.50      0.60         6
# finger-double-click       0.70      0.88      0.78         8
#   finger-fling-down       1.00      0.33      0.50         3
#   finger-fling-left       0.75      0.75      0.75         4
#  finger-fling-right       0.00      0.00      0.00         4
#     finger-fling-up       0.00      0.00      0.00         1
#         finger-snap       0.00      0.00      0.00         2
#   finger-swipe-down       0.00      0.00      0.00         4
#   finger-swipe-left       0.25      0.33      0.29         6
#  finger-swipe-right       0.56      0.62      0.59         8
#     finger-swipe-up       0.45      1.00      0.62         5
#          fist_pound       0.33      0.75      0.46         4
#         mouse-click       1.00      0.50      0.67         2
#          mouse-move       1.00      0.80      0.89         5
#     nail-fling-down       0.75      0.60      0.67         5
#     nail-fling-left       0.40      0.67      0.50         3
#    nail-fling-right       0.00      0.00      0.00         4
#       nail-fling-up       0.50      0.50      0.50         4
#          no-gesture       0.71      1.00      0.83         5
#                slap       0.67      0.33      0.44         6
#    tap-singlefinger       1.00      0.67      0.80         6
#              typing       0.86      1.00      0.92         6
#
#            accuracy                           0.57       101
#           macro avg       0.53      0.51      0.49       101
#        weighted avg       0.58      0.57      0.55       101
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report
import os

# 读取数据
folder_path = 'DNN data'
features_scaled = np.load(os.path.join(folder_path, 'features_scaled.npy'))
labels = np.load(os.path.join(folder_path, 'labels.npy'))

# 将标签从字符串转换为整数
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# 分割数据集
X_train, X_test, y_train, y_test = train_test_split(features_scaled, labels_encoded, test_size=0.25, random_state=42)

# 定义模型
model = Sequential()
model.add(Dense(256, input_dim=10136, activation='relu', kernel_regularizer='l2'))  # 使用正则化
model.add(BatchNormalization())  # 添加批量归一化层
model.add(Dropout(0.3))  # 使用Dropout减少过拟合
model.add(Dense(128, activation='relu', kernel_regularizer='l2'))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu', kernel_regularizer='l2'))  # 减小层的规模以适应小数据集
model.add(Dense(len(np.unique(labels_encoded)), activation='softmax'))  # 输出层

# 编译模型
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 设置回调函数
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001, verbose=1)

# 训练模型
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1, callbacks=[early_stopping, reduce_lr])

# 评估模型
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss:.2f}")
print(f"Test Accuracy: {accuracy*100:.2f}%")

# 预测并输出分类报告
predictions = model.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)
print(classification_report(y_test, predicted_classes, target_names=encoder.classes_))
# Out:
# Epoch 1/100
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.0992 - loss: 10.9321 - val_accuracy: 0.1475 - val_loss: 10.7163 - learning_rate: 0.0010
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2018 - loss: 9.6407 - val_accuracy: 0.2295 - val_loss: 9.9412 - learning_rate: 0.0010
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3428 - loss: 8.8361 - val_accuracy: 0.2623 - val_loss: 9.1854 - learning_rate: 0.0010
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4935 - loss: 8.1185 - val_accuracy: 0.2131 - val_loss: 8.4374 - learning_rate: 0.0010
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5930 - loss: 7.4144 - val_accuracy: 0.2295 - val_loss: 7.7776 - learning_rate: 0.0010
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5915 - loss: 6.8631 - val_accuracy: 0.2623 - val_loss: 7.2594 - learning_rate: 0.0010
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6290 - loss: 6.2989 - val_accuracy: 0.2623 - val_loss: 6.7609 - learning_rate: 0.0010
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7257 - loss: 5.7743 - val_accuracy: 0.2787 - val_loss: 6.3311 - learning_rate: 0.0010
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6992 - loss: 5.4376 - val_accuracy: 0.2951 - val_loss: 5.9649 - learning_rate: 0.0010
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7282 - loss: 5.0774 - val_accuracy: 0.3443 - val_loss: 5.6863 - learning_rate: 0.0010
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7278 - loss: 4.7630 - val_accuracy: 0.4098 - val_loss: 5.4601 - learning_rate: 0.0010
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7510 - loss: 4.5094 - val_accuracy: 0.4590 - val_loss: 5.2412 - learning_rate: 0.0010
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7764 - loss: 4.2595 - val_accuracy: 0.4262 - val_loss: 5.1187 - learning_rate: 0.0010
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7622 - loss: 4.0850 - val_accuracy: 0.4262 - val_loss: 4.9936 - learning_rate: 0.0010
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7879 - loss: 3.8844 - val_accuracy: 0.4918 - val_loss: 4.8850 - learning_rate: 0.0010
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7885 - loss: 3.7222 - val_accuracy: 0.4918 - val_loss: 4.6989 - learning_rate: 0.0010
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7282 - loss: 3.6798 - val_accuracy: 0.4426 - val_loss: 4.6236 - learning_rate: 0.0010
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7848 - loss: 3.5166 - val_accuracy: 0.4262 - val_loss: 4.4409 - learning_rate: 0.0010
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8443 - loss: 3.2901 - val_accuracy: 0.4590 - val_loss: 4.2494 - learning_rate: 0.0010
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8323 - loss: 3.2222 - val_accuracy: 0.4918 - val_loss: 4.1798 - learning_rate: 0.0010
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7986 - loss: 3.1841 - val_accuracy: 0.4262 - val_loss: 4.1641 - learning_rate: 0.0010
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7718 - loss: 3.1501 - val_accuracy: 0.5246 - val_loss: 4.1049 - learning_rate: 0.0010
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8347 - loss: 2.9635 - val_accuracy: 0.4590 - val_loss: 4.0086 - learning_rate: 0.0010
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8136 - loss: 2.9203 - val_accuracy: 0.4590 - val_loss: 3.9300 - learning_rate: 0.0010
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8169 - loss: 2.8018 - val_accuracy: 0.4918 - val_loss: 3.8706 - learning_rate: 0.0010
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8296 - loss: 2.6811 - val_accuracy: 0.4918 - val_loss: 3.8261 - learning_rate: 0.0010
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8237 - loss: 2.6842 - val_accuracy: 0.4754 - val_loss: 3.8109 - learning_rate: 0.0010
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8386 - loss: 2.6100 - val_accuracy: 0.4918 - val_loss: 3.7508 - learning_rate: 0.0010
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8254 - loss: 2.5905 - val_accuracy: 0.4918 - val_loss: 3.6953 - learning_rate: 0.0010
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8116 - loss: 2.5535 - val_accuracy: 0.4918 - val_loss: 3.6883 - learning_rate: 0.0010
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8408 - loss: 2.4859 - val_accuracy: 0.5082 - val_loss: 3.5554 - learning_rate: 0.0010
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8819 - loss: 2.4173 - val_accuracy: 0.4426 - val_loss: 3.5094 - learning_rate: 0.0010
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8449 - loss: 2.4331 - val_accuracy: 0.4918 - val_loss: 3.4719 - learning_rate: 0.0010
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8355 - loss: 2.2888 - val_accuracy: 0.5082 - val_loss: 3.3464 - learning_rate: 0.0010
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8564 - loss: 2.2623 - val_accuracy: 0.5082 - val_loss: 3.2864 - learning_rate: 0.0010
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8161 - loss: 2.2569 - val_accuracy: 0.4098 - val_loss: 3.3601 - learning_rate: 0.0010
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8417 - loss: 2.2152 - val_accuracy: 0.4918 - val_loss: 3.2296 - learning_rate: 0.0010
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8936 - loss: 2.0785 - val_accuracy: 0.5246 - val_loss: 3.2574 - learning_rate: 0.0010
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8466 - loss: 2.1428 - val_accuracy: 0.5082 - val_loss: 3.2334 - learning_rate: 0.0010
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8737 - loss: 2.0819 - val_accuracy: 0.5082 - val_loss: 3.2633 - learning_rate: 0.0010
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8388 - loss: 2.1246 - val_accuracy: 0.4590 - val_loss: 3.1189 - learning_rate: 0.0010
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8375 - loss: 2.0690 - val_accuracy: 0.4426 - val_loss: 3.0828 - learning_rate: 0.0010
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8102 - loss: 2.0496 - val_accuracy: 0.5082 - val_loss: 3.2019 - learning_rate: 0.0010
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8676 - loss: 1.9903 - val_accuracy: 0.5082 - val_loss: 3.2335 - learning_rate: 0.0010
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8532 - loss: 1.9867 - val_accuracy: 0.4262 - val_loss: 3.1745 - learning_rate: 0.0010
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8382 - loss: 1.9830 - val_accuracy: 0.4590 - val_loss: 3.0655 - learning_rate: 0.0010
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9058 - loss: 1.8465 - val_accuracy: 0.5574 - val_loss: 3.0039 - learning_rate: 0.0010
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8164 - loss: 1.9406 - val_accuracy: 0.5082 - val_loss: 3.0160 - learning_rate: 0.0010
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8277 - loss: 1.8571 - val_accuracy: 0.5246 - val_loss: 3.0326 - learning_rate: 0.0010
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8423 - loss: 1.9217 - val_accuracy: 0.4918 - val_loss: 3.0405 - learning_rate: 0.0010
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8220 - loss: 1.8970 - val_accuracy: 0.3934 - val_loss: 3.3103 - learning_rate: 0.0010
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8924 - loss: 1.8384
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8864 - loss: 1.8467 - val_accuracy: 0.4918 - val_loss: 3.0889 - learning_rate: 0.0010
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8844 - loss: 1.8235 - val_accuracy: 0.4754 - val_loss: 3.0502 - learning_rate: 2.0000e-04
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8749 - loss: 1.8239 - val_accuracy: 0.5410 - val_loss: 2.9439 - learning_rate: 2.0000e-04
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8912 - loss: 1.7387 - val_accuracy: 0.5738 - val_loss: 2.8940 - learning_rate: 2.0000e-04
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8883 - loss: 1.6835 - val_accuracy: 0.5574 - val_loss: 2.8490 - learning_rate: 2.0000e-04
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8896 - loss: 1.7069 - val_accuracy: 0.5574 - val_loss: 2.8269 - learning_rate: 2.0000e-04
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8670 - loss: 1.6781 - val_accuracy: 0.5246 - val_loss: 2.7959 - learning_rate: 2.0000e-04
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8841 - loss: 1.6002 - val_accuracy: 0.5246 - val_loss: 2.8207 - learning_rate: 2.0000e-04
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8906 - loss: 1.6181 - val_accuracy: 0.4590 - val_loss: 2.9102 - learning_rate: 2.0000e-04
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9314 - loss: 1.5065 - val_accuracy: 0.4754 - val_loss: 2.8920 - learning_rate: 2.0000e-04
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9237 - loss: 1.5095 - val_accuracy: 0.4754 - val_loss: 2.7945 - learning_rate: 2.0000e-04
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9078 - loss: 1.5008 - val_accuracy: 0.4590 - val_loss: 2.7744 - learning_rate: 2.0000e-04
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8818 - loss: 1.5382 - val_accuracy: 0.5246 - val_loss: 2.6942 - learning_rate: 2.0000e-04
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9184 - loss: 1.4570 - val_accuracy: 0.4590 - val_loss: 2.7005 - learning_rate: 2.0000e-04
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9364 - loss: 1.4066 - val_accuracy: 0.4262 - val_loss: 2.7371 - learning_rate: 2.0000e-04
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8836 - loss: 1.4722 - val_accuracy: 0.4262 - val_loss: 2.7615 - learning_rate: 2.0000e-04
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9240 - loss: 1.4016 - val_accuracy: 0.4590 - val_loss: 2.6916 - learning_rate: 2.0000e-04
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8997 - loss: 1.3753 - val_accuracy: 0.4918 - val_loss: 2.7315 - learning_rate: 2.0000e-04
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8771 - loss: 1.4437 - val_accuracy: 0.4426 - val_loss: 2.7488 - learning_rate: 2.0000e-04
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8997 - loss: 1.3471 - val_accuracy: 0.4098 - val_loss: 2.8399 - learning_rate: 2.0000e-04
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9347 - loss: 1.3083 - val_accuracy: 0.4098 - val_loss: 2.7879 - learning_rate: 2.0000e-04
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9178 - loss: 1.3285
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.0001.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9186 - loss: 1.3278 - val_accuracy: 0.4262 - val_loss: 2.7374 - learning_rate: 2.0000e-04
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9254 - loss: 1.3017 - val_accuracy: 0.4262 - val_loss: 2.7213 - learning_rate: 1.0000e-04
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9168 - loss: 1.2926 - val_accuracy: 0.4262 - val_loss: 2.7471 - learning_rate: 1.0000e-04
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9154 - loss: 1.2887 - val_accuracy: 0.4426 - val_loss: 2.7619 - learning_rate: 1.0000e-04
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9233 - loss: 1.2568 - val_accuracy: 0.4426 - val_loss: 2.7798 - learning_rate: 1.0000e-04
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9339 - loss: 1.2354 - val_accuracy: 0.4098 - val_loss: 2.8006 - learning_rate: 1.0000e-04
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5247 - loss: 2.3769
# Test Loss: 2.42
# Test Accuracy: 51.49%
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#                      precision    recall  f1-score   support
#
#               alarm       1.00      0.50      0.67         6
# finger-double-click       0.71      0.62      0.67         8
#   finger-fling-down       0.50      0.67      0.57         3
#   finger-fling-left       0.50      0.75      0.60         4
#  finger-fling-right       0.00      0.00      0.00         4
#     finger-fling-up       0.20      1.00      0.33         1
#         finger-snap       0.00      0.00      0.00         2
#   finger-swipe-down       0.00      0.00      0.00         4
#   finger-swipe-left       0.27      0.50      0.35         6
#  finger-swipe-right       0.57      0.50      0.53         8
#     finger-swipe-up       0.60      0.60      0.60         5
#          fist_pound       0.43      0.75      0.55         4
#         mouse-click       0.33      1.00      0.50         2
#          mouse-move       0.71      1.00      0.83         5
#     nail-fling-down       1.00      0.60      0.75         5
#     nail-fling-left       0.50      0.67      0.57         3
#    nail-fling-right       0.00      0.00      0.00         4
#       nail-fling-up       0.50      0.75      0.60         4
#          no-gesture       0.60      0.60      0.60         5
#                slap       0.67      0.33      0.44         6
#    tap-singlefinger       1.00      0.33      0.50         6
#              typing       0.60      0.50      0.55         6
#
#            accuracy                           0.51       101
#           macro avg       0.49      0.53      0.46       101
#        weighted avg       0.55      0.51      0.50       101
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/pengyuecheng/Documents/UW/TECHIN 515/final/python/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
